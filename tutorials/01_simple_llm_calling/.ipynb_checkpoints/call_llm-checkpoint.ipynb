# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
import os
load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(model="gemma-4-31b-it", temperature=0)
response=llm.invoke("How many moons does Jupeter have?")
print(response.text)
# Out:
# Jupiter has **95 officially recognized moons**.
#
# This number often changes as astronomers discover new, smaller moons orbiting the planet. The most famous of these are the four largest, known as the **Galilean moons**: Io, Europa, Ganymede, and Callisto.

# %%
response=llm.invoke([
    ["system","You are a helpful assistant that answers in short one line"],
    ["human", "Who is better? Messi or kukurela"]
])
print(response.text)
# Out:
# Lionel Messi is widely considered far superior.

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="qwen/qwen3.6-27b", reasoning_format="parsed")
messages=[
    ("system", "You are a helpful assistant that answers in "),
    ("human", "I habe bin working für sevral days: corrrect this sententce")
]
response=llm.invoke(messages)
print(response.text)
# Out:
# "I have been working for several days."
